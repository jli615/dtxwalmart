# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/marknour/Desktop/walmart/newwalmart/dtxwalmart/4_23_cleaned_data.csv")
df = df.drop(columns=["Unnamed: 0"])
df
# Out:
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3690976654.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/marknour/Desktop/walmart/newwalmart/dtxwalmart/4_23_cleaned_data.csv")
#         Location ID                             Location Name  \
# 0              3615  Neighborhood Market FM Reg14-12 INSOURCE
# 1               830                       Walmart FM Reg 12-2
# 2              3261                   Supercenter FM Reg 12-3
# 3              2733                   Supercenter FM Reg 11-2
# 4              1059         Supercenter FM Reg 15-10 INSOURCE
# ...             ...                                       ...
# 413705         5370                            WM Supercenter
# 413706         4839                                Sam's Club
# 413707         6631                                Sam's Club
# 413708          720                            WM Supercenter
# 413709         5219                            WM Supercenter
#
#                         Address        Provider        Trade  \
# 0               2217 NW 23RD ST        Westrock  SOLID WASTE
# 1                  1901 1ST AVE  Rubicon Global  SOLID WASTE
# 2             2801 DUPORTAIL ST  Rubicon Global  SOLID WASTE
# 3        1009 SAINT PATRICKS DR        Westrock  SOLID WASTE
# 4             1309 HIGHWAY 35 S        Westrock  SOLID WASTE
# ...                         ...             ...          ...
# 413705             2514 MAIN ST             NaN          NaN
# 413706  7757 S OLYMPIA AVENUE W             NaN          NaN
# 413707         880 S ABILENE ST             NaN          NaN
# 413708       301 LEONARDWOOD RD             NaN          NaN
# 413709     550 CONGRESSIONAL DR             NaN          NaN
#
#                  Category                               ProblemCode  Tonnage  \
# 0       REPAIR - REACTIVE           Empty and Return (not a repair)     1.51
# 1       REPAIR - REACTIVE           Empty and Return (not a repair)     2.78
# 2             MAINTENANCE  Compactor is full and needs to be hauled     6.75
# 3             MAINTENANCE  Compactor is full and needs to be hauled    10.86
# 4             MAINTENANCE  Compactor is full and needs to be hauled     3.88
# ...                   ...                                       ...      ...
# 413705                NaN                                       NaN     7.75
# 413706                NaN                                       NaN     9.33
# 413707                NaN                                       NaN     7.63
# 413708                NaN                                       NaN     9.54
# 413709                NaN                                       NaN     8.55
#
#        Completed Date  Region  District Priority  Zip code           City  \
# 0          2020-11-03    64.0     533.0      NaN       NaN  OKLAHOMA CITY
# 1          2020-11-10    25.0     279.0      NaN       NaN     ROCK FALLS
# 2          2020-11-20    60.0     475.0      NaN       NaN       RICHLAND
# 3          2020-11-27     2.0      32.0      NaN       NaN          PERRY
# 4          2020-12-01    11.0     138.0      NaN       NaN         FOREST
# ...               ...     ...       ...      ...       ...            ...
# 413705     2024-01-31     NaN       NaN      NaN   80504.0       LONGMONT
# 413706     2024-01-31     NaN       NaN      NaN   74132.0          TULSA
# 413707     2024-01-31     NaN       NaN      NaN   80012.0         AURORA
# 413708     2024-01-31     NaN       NaN      NaN   40601.0      FRANKFORT
# 413709     2024-01-31     NaN       NaN      NaN   66049.0       LAWRENCE
#
#        State   Latitude   Longitude
# 0         OK  35.494581  -97.550623
# 1         IL  41.763361  -89.687051
# 2         WA  46.255981 -119.307922
# 3         GA  32.472626  -83.739099
# 4         MS  32.338638  -89.486173
# ...      ...        ...         ...
# 413705    CO  40.205153 -105.098807
# 413706    OK  36.050971  -96.003787
# 413707    CO  39.700498 -104.825655
# 413708    KY  38.160546  -84.899191
# 413709    KS  38.973379  -95.309818
#
# [413710 rows x 17 columns]

# %%
# supercenter_20 = df[df['Completed Date'].dt.year == 2020]
# supercenter_21 = df[df['Completed Date'].dt.year == 2021]
# supercenter_22 = df[df['Completed Date'].dt.year == 2022]
# supercenter_23 = df[df['Completed Date'].dt.year == 2023]
# supercenter_24 = df[df['Completed Date'].dt.year == 2024]

# %%
# non_supercenter_20 = df[df['Completed Date'].dt.year == 2020]
# non_supercenter_21 = df[df['Completed Date'].dt.year == 2021]
# non_supercenter_22 = df[df['Completed Date'].dt.year == 2022]
# non_supercenter_23 = df[df['Completed Date'].dt.year == 2023]
# non_supercenter_24 = df[df['Completed Date'].dt.year == 2024]

# %%
df
# Out:
#         Location ID                             Location Name  \
# 0              3615  Neighborhood Market FM Reg14-12 INSOURCE
# 1               830                       Walmart FM Reg 12-2
# 2              3261                   Supercenter FM Reg 12-3
# 3              2733                   Supercenter FM Reg 11-2
# 4              1059         Supercenter FM Reg 15-10 INSOURCE
# ...             ...                                       ...
# 413705         5370                            WM Supercenter
# 413706         4839                                Sam's Club
# 413707         6631                                Sam's Club
# 413708          720                            WM Supercenter
# 413709         5219                            WM Supercenter
#
#                         Address        Provider        Trade  \
# 0               2217 NW 23RD ST        Westrock  SOLID WASTE
# 1                  1901 1ST AVE  Rubicon Global  SOLID WASTE
# 2             2801 DUPORTAIL ST  Rubicon Global  SOLID WASTE
# 3        1009 SAINT PATRICKS DR        Westrock  SOLID WASTE
# 4             1309 HIGHWAY 35 S        Westrock  SOLID WASTE
# ...                         ...             ...          ...
# 413705             2514 MAIN ST             NaN          NaN
# 413706  7757 S OLYMPIA AVENUE W             NaN          NaN
# 413707         880 S ABILENE ST             NaN          NaN
# 413708       301 LEONARDWOOD RD             NaN          NaN
# 413709     550 CONGRESSIONAL DR             NaN          NaN
#
#                  Category                               ProblemCode  Tonnage  \
# 0       REPAIR - REACTIVE           Empty and Return (not a repair)     1.51
# 1       REPAIR - REACTIVE           Empty and Return (not a repair)     2.78
# 2             MAINTENANCE  Compactor is full and needs to be hauled     6.75
# 3             MAINTENANCE  Compactor is full and needs to be hauled    10.86
# 4             MAINTENANCE  Compactor is full and needs to be hauled     3.88
# ...                   ...                                       ...      ...
# 413705                NaN                                       NaN     7.75
# 413706                NaN                                       NaN     9.33
# 413707                NaN                                       NaN     7.63
# 413708                NaN                                       NaN     9.54
# 413709                NaN                                       NaN     8.55
#
#        Completed Date  Region  District Priority  Zip code           City  \
# 0          2020-11-03    64.0     533.0      NaN       NaN  OKLAHOMA CITY
# 1          2020-11-10    25.0     279.0      NaN       NaN     ROCK FALLS
# 2          2020-11-20    60.0     475.0      NaN       NaN       RICHLAND
# 3          2020-11-27     2.0      32.0      NaN       NaN          PERRY
# 4          2020-12-01    11.0     138.0      NaN       NaN         FOREST
# ...               ...     ...       ...      ...       ...            ...
# 413705     2024-01-31     NaN       NaN      NaN   80504.0       LONGMONT
# 413706     2024-01-31     NaN       NaN      NaN   74132.0          TULSA
# 413707     2024-01-31     NaN       NaN      NaN   80012.0         AURORA
# 413708     2024-01-31     NaN       NaN      NaN   40601.0      FRANKFORT
# 413709     2024-01-31     NaN       NaN      NaN   66049.0       LAWRENCE
#
#        State   Latitude   Longitude
# 0         OK  35.494581  -97.550623
# 1         IL  41.763361  -89.687051
# 2         WA  46.255981 -119.307922
# 3         GA  32.472626  -83.739099
# 4         MS  32.338638  -89.486173
# ...      ...        ...         ...
# 413705    CO  40.205153 -105.098807
# 413706    OK  36.050971  -96.003787
# 413707    CO  39.700498 -104.825655
# 413708    KY  38.160546  -84.899191
# 413709    KS  38.973379  -95.309818
#
# [413710 rows x 17 columns]

# %%
# df.to_csv("/Users/marknour/Desktop/walmart/newwalmart/dtxwalmart/4_23_cleaned_data.csv")

# %%
df['Completed Date'] = pd.to_datetime(df['Completed Date'])

# Sort by 'Location ID' and 'Completed Date'
df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups
df['Days Since Last Pickup'] = df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup
pickup_frequency_sd = df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd.quantile(0.95))


## Plot the distribution of standard deviations
plt.figure(figsize=(10, 5))
pickup_frequency_sd.hist(bins=100, alpha=0.7, color='blue')
plt.title('Distribution of Standard Deviations of Pickup Frequency Across Stores')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 145.22427123449307

# %%
pickup_frequency_sd.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Location ID
# 1         2.310417
# 2         3.485319
# 3         5.603197
# 4         6.475524
# 5         0.707107
#            ...
# 9836     43.167971
# 9930     20.342973
# 30026    14.349137
# 30095    71.617536
# 30099    24.062419
# Name: Days Since Last Pickup, Length: 4717, dtype: float64>

# %%
# Define the threshold
threshold = 50

# Count the number of stores with a standard deviation above the threshold
stores_above_threshold = (pickup_frequency_sd > threshold).sum()

print(f"Number of stores with a standard deviation above {threshold}: {stores_above_threshold}")
# Out:
# Number of stores with a standard deviation above 50: 782

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]

# Sort by 'Location ID' and 'Completed Date'
supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for supercenters
supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for supercenters
pickup_frequency_sd_supercenters = supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_supercenters.hist(bins=100, alpha=0.7, color='blue')
plt.title('Distribution of Standard Deviations of Pickup Frequency for Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 140.14803838452434
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/602085147.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/602085147.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df = df[~df['Location Name'].str.contains('Supercenter', na=False)]


# Sort by 'Location ID' and 'Completed Date'
non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for non-supercenters
non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for non-supercenters
pickup_frequency_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()

print(pickup_frequency_sd_non_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for non-supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_non_supercenters.hist(bins=100, alpha=0.7, color='red')
plt.title('Distribution of Standard Deviations of Pickup Frequency for Non-Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 175.34689933173564
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/1305008413.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/1305008413.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df= df[~df['Location Name'].str.contains('Supercenter', na=False)]
non_supercenters_df = df[df['Completed Date'].dt.year == 2020]


# Sort by 'Location ID' and 'Completed Date'
non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for non-supercenters
non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for non-supercenters
pickup_frequency_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()

print(pickup_frequency_sd_non_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for non-supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_non_supercenters.hist(bins=100, alpha=0.7, color='red')
plt.title('2020 Distribution of Standard Deviations of Pickup Frequency for Non-Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 9.899494936611665
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/2691149614.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/2691149614.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df= df[~df['Location Name'].str.contains('Supercenter', na=False)]
non_supercenters_df = df[df['Completed Date'].dt.year == 2021]


# Sort by 'Location ID' and 'Completed Date'
non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for non-supercenters
non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for non-supercenters
pickup_frequency_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()

print(pickup_frequency_sd_non_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for non-supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_non_supercenters.hist(bins=100, alpha=0.7, color='red')
plt.title('2021 Distribution of Standard Deviations of Pickup Frequency for Non-Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 22.654757404347638
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3653398348.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3653398348.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df= df[~df['Location Name'].str.contains('Supercenter', na=False)]
non_supercenters_df = df[df['Completed Date'].dt.year == 2022]


# Sort by 'Location ID' and 'Completed Date'
non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for non-supercenters
non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for non-supercenters
pickup_frequency_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()

print(pickup_frequency_sd_non_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for non-supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_non_supercenters.hist(bins=100, alpha=0.7, color='red')
plt.title('2022 Distribution of Standard Deviations of Pickup Frequency for Non-Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 15.824750062808118
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/4271625959.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/4271625959.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df= df[~df['Location Name'].str.contains('Supercenter', na=False)]
non_supercenters_df = df[df['Completed Date'].dt.year == 2023]


# Sort by 'Location ID' and 'Completed Date'
non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for non-supercenters
non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for non-supercenters
pickup_frequency_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()

print(pickup_frequency_sd_non_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for non-supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_non_supercenters.hist(bins=100, alpha=0.7, color='red')
plt.title('2023 Distribution of Standard Deviations of Pickup Frequency for Non-Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 18.518445093999347
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/2236708316.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/2236708316.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df= df[~df['Location Name'].str.contains('Supercenter', na=False)]
non_supercenters_df = df[df['Completed Date'].dt.year == 2024]


# Sort by 'Location ID' and 'Completed Date'
non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for non-supercenters
non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for non-supercenters
pickup_frequency_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()

print(pickup_frequency_sd_non_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for non-supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_non_supercenters.hist(bins=100, alpha=0.7, color='red')
plt.title('2024 Distribution of Standard Deviations of Pickup Frequency for Non-Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 6.363961030678928
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/4064659162.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/4064659162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_supercenters_df['Days Since Last Pickup'] = non_supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Define the threshold
threshold = 100

# Count the number of stores with a standard deviation above the threshold
stores_above_threshold = (pickup_frequency_sd > threshold).sum()

print(f"Number of stores with a standard deviation above {threshold}: {stores_above_threshold}")
# Out:
# Number of stores with a standard deviation above 100: 644

# %% [markdown]
# # Supercenter Pickup Frequency Per Year

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]
supercenters_df = df[df['Completed Date'].dt.year == 2020]

# Sort by 'Location ID' and 'Completed Date'
supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for supercenters
supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for supercenters
pickup_frequency_sd_supercenters = supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_supercenters.hist(bins=100, alpha=0.7, color='blue')
plt.title('2020 Distribution of Standard Deviations of Pickup Frequency for Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 9.899494936611665
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/2145760399.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/2145760399.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]
supercenters_df = df[df['Completed Date'].dt.year == 2021]

# Sort by 'Location ID' and 'Completed Date'
supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for supercenters
supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for supercenters
pickup_frequency_sd_supercenters = supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_supercenters.hist(bins=100, alpha=0.7, color='blue')
plt.title('2021 Distribution of Standard Deviations of Pickup Frequency for Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 22.654757404347638
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3923102410.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3923102410.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]
supercenters_df = df[df['Completed Date'].dt.year == 2022]

# Sort by 'Location ID' and 'Completed Date'
supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for supercenters
supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for supercenters
pickup_frequency_sd_supercenters = supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_supercenters.hist(bins=100, alpha=0.7, color='blue')
plt.title('2022 Distribution of Standard Deviations of Pickup Frequency for Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 15.824750062808118
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3083223840.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/3083223840.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]
supercenters_df = df[df['Completed Date'].dt.year == 2023]

# Sort by 'Location ID' and 'Completed Date'
supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for supercenters
supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for supercenters
pickup_frequency_sd_supercenters = supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_supercenters.hist(bins=100, alpha=0.7, color='blue')
plt.title('2023 Distribution of Standard Deviations of Pickup Frequency for Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 18.518445093999347
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/1251855008.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/1251855008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]
supercenters_df = df[df['Completed Date'].dt.year == 2024]

# Sort by 'Location ID' and 'Completed Date'
supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)

# Calculate the difference in days between consecutive pickups for supercenters
supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# Group by 'Location ID' and calculate the standard deviation of the days since last pickup for supercenters
pickup_frequency_sd_supercenters = supercenters_df.groupby('Location ID')['Days Since Last Pickup'].std()


print(pickup_frequency_sd_supercenters.quantile(0.95))

## Plot the distribution of standard deviations for supercenters
plt.figure(figsize=(10, 5))
pickup_frequency_sd_supercenters.hist(bins=100, alpha=0.7, color='blue')
plt.title('2024 Distribution of Standard Deviations of Pickup Frequency for Supercenters')
plt.xlabel('Standard Deviation of Days Since Last Pickup')
plt.ylabel('Frequency')
plt.show()
# Out:
# 6.363961030678928
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/4234842302.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df.sort_values(by=['Location ID', 'Completed Date'], inplace=True)
# /var/folders/xk/vtbll1l13rx3vyfrm7k9h0lr0000gn/T/ipykernel_7042/4234842302.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supercenters_df['Days Since Last Pickup'] = supercenters_df.groupby('Location ID')['Completed Date'].diff().dt.days

# %%
df['Completed Date'] = pd.to_datetime(df['Completed Date'])

# Group by 'Location ID' and calculate SD for Tonnage
tonnage_sd = df.groupby('Location ID')['Tonnage'].std()


print("SD of Tonnage for each store:")
print(tonnage_sd)


print(tonnage_sd.quantile(0.95))


### Step 2: Analyze Distribution

# Distribution of SDs for tonnage
plt.figure(figsize=(10, 5))
plt.hist(tonnage_sd.dropna(), bins=100, color='blue', label='Tonnage SD', range=(0, 10))  # limiting range to (0, 200)
plt.title('Distribution of Standard Deviations for Tonnage Across Stores')
plt.xlabel('Standard Deviation of Tonnage')
plt.ylabel('Frequency')
plt.show()
# Adjust the histogram plot to have x-axis ticks every unit instead of every 2
# plt.figure(figsize=(10, 5))
# plt.hist(tonnage_sd.dropna(), bins=range(int(tonnage_sd.dropna().min()), int(tonnage_sd.dropna().max()) + 1, 1), color='blue', label='Tonnage SD')
# plt.xticks(range(int(tonnage_sd.dropna().min()), int(tonnage_sd.dropna().max()) + 1, 1))  # Set x ticks at every 1 unit
# plt.title('Distribution of Standard Deviations for Tonnage Across Stores')
# plt.xlabel('Standard Deviation of Tonnage')
# plt.ylabel('Frequency')
# plt.grid(True)
# plt.tight_layout()
# plt.show()
# Out:
# SD of Tonnage for each store:
# Location ID
# 1        2.318375
# 2        2.154496
# 3        2.930657
# 4        3.166434
# 5        0.000000
#            ...
# 9836     3.445908
# 9930     4.968279
# 30026    3.418430
# 30095    4.990391
# 30099    1.494579
# Name: Tonnage, Length: 4717, dtype: float64
# 3.96150863822896

# %%
# Filter the dataframe for rows where 'Location Name' contains 'Supercenter'
supercenters_df = df[df['Location Name'].str.contains('Supercenter', na=False)]

# Group by 'Location ID' and calculate SD for Tonnage for supercenters
tonnage_sd_supercenters = supercenters_df.groupby('Location ID')['Tonnage'].std()

print("SD of Tonnage for Supercenters:")
print(tonnage_sd_supercenters)
print(tonnage_sd_supercenters.quantile(0.95))

### Step 2: Analyze Distribution

# Distribution of SDs for tonnage for supercenters
plt.figure(figsize=(10, 5))
tonnage_sd_supercenters.hist(bins=100, color='blue', label='Tonnage SD', range=(0, 10))  # limiting range to (0, 10)
plt.title('Distribution of Standard Deviations for Tonnage at Supercenters')
plt.xlabel('Standard Deviation of Tonnage')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# SD of Tonnage for Supercenters:
# Location ID
# 1       2.318375
# 2       2.154496
# 3       2.930657
# 4       3.166434
# 5       0.000000
#           ...
# 7301    2.209908
# 7324    3.540868
# 7326    2.077192
# 8331    3.652029
# 8930    3.706050
# Name: Tonnage, Length: 3481, dtype: float64
# 3.8758673890402164

# %%
# Filter the dataframe for rows where 'Location Name' does NOT contain 'Supercenter'
non_supercenters_df = df[~df['Location Name'].str.contains('Supercenter', na=False)]

# Group by 'Location ID' and calculate SD for Tonnage for non-supercenters
tonnage_sd_non_supercenters = non_supercenters_df.groupby('Location ID')['Tonnage'].std()

print("SD of Tonnage for Non-Supercenters:")
print(tonnage_sd_non_supercenters)
print(tonnage_sd_non_supercenters.quantile(0.95))

### Step 2: Analyze Distribution

# Distribution of SDs for tonnage for non-supercenters
plt.figure(figsize=(10, 5))
tonnage_sd_non_supercenters.hist(bins=100, color='red', label='Tonnage SD', range=(0, 10))  # limiting range to (0, 10)
plt.title('Distribution of Standard Deviations for Tonnage at Non-Supercenters')
plt.xlabel('Standard Deviation of Tonnage')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# SD of Tonnage for Non-Supercenters:
# Location ID
# 32       2.502500
# 44            NaN
# 51            NaN
# 57            NaN
# 60       1.022073
#            ...
# 9836     3.445908
# 9930     4.968279
# 30026    3.418430
# 30095    4.990391
# 30099    1.494579
# Name: Tonnage, Length: 1313, dtype: float64
# 4.202932249996153

# %%
# Group by 'Location ID' and calculate mean for Tonnage
tonnage_mean = df.groupby('Location ID')['Tonnage'].mean()

print("Mean Tonnage for each store:")
print(tonnage_mean)

### Step 2: Analyze Distribution

# Distribution of means for tonnage
plt.figure(figsize=(10, 5))
plt.hist(tonnage_mean.dropna(), bins=100, color='green', label='Tonnage Mean', range=(0, 50))  # Set x-axis max to 50
plt.title('Distribution of Mean Tonnage Across Stores')
plt.xlabel('Mean Tonnage')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Mean Tonnage for each store:
# Location ID
# 1         7.133357
# 2         7.692941
# 3         5.183171
# 4         6.776476
# 5         0.000000
#            ...
# 9836      5.410500
# 9930     11.158750
# 30026     7.255588
# 30095     8.063333
# 30099     9.545000
# Name: Tonnage, Length: 4717, dtype: float64

# %%
# Replace '5' with the actual Location ID of the store you're interested in
store_id = 4
store_data = df[df['Location ID'] == store_id]

# Calculate mean and standard deviation
mean_tonnage = store_data['Tonnage'].mean()
std_tonnage = store_data['Tonnage'].std()

# Calculate one standard deviation from the mean
one_std_above = mean_tonnage + std_tonnage
one_std_below = mean_tonnage - std_tonnage

print(f"For store {store_id}, the mean tonnage is: {mean_tonnage}")
print(f"One standard deviation above the mean is: {one_std_above}")
print(f"One standard deviation below the mean is: {one_std_below}")
# Out:
# For store 4, the mean tonnage is: 6.77647619047619
# One standard deviation above the mean is: 9.942909813094369
# One standard deviation below the mean is: 3.610042567858011

# %%
# store_5_tonnage = df[df['Location ID'] == 5]['Tonnage'].unique
# print(f"Tonnages for store #5:\n{store_5_tonnage}")

# %% [markdown]
# # Extra EDA

# %%
# Find stores with any tonnage value over 500
mask = df['Tonnage'] > 37
stores_with_large_tonnage = df.loc[mask, 'Location ID'].unique()

# Drop rows where tonnage is over 500 for those stores
df = df[~((df['Location ID'].isin(stores_with_large_tonnage)) & (df['Tonnage'] > 37))]

df
# Out:
#         Location ID                     Location Name           Address  \
# 4607              1  Supercenter FM Reg 10-9 INSOURCE  2110 W WALNUT ST
# 5603              1  Supercenter FM Reg 10-9 INSOURCE  2110 W WALNUT ST
# 8484              1  Supercenter FM Reg 10-9 INSOURCE  2110 W WALNUT ST
# 11032             1  Supercenter FM Reg 10-9 INSOURCE  2110 W WALNUT ST
# 11936             1                    WM Supercenter  2110 W WALNUT ST
# ...             ...                               ...               ...
# 413140        30095                           Unknown  2403 SE J Street
# 181439        30099                           Unknown      2914 SE I ST
# 247041        30099                           Unknown      2914 SE I ST
# 326393        30099                           Unknown      2914 SE I ST
# 392595        30099                           Unknown      2914 SE I ST
#
#         Provider        Trade     Category  \
# 4607    Westrock  SOLID WASTE  MAINTENANCE
# 5603    Westrock  SOLID WASTE  MAINTENANCE
# 8484    Westrock  SOLID WASTE  MAINTENANCE
# 11032   Westrock  SOLID WASTE  MAINTENANCE
# 11936        NaN          NaN          NaN
# ...          ...          ...          ...
# 413140       NaN          NaN          NaN
# 181439       NaN          NaN          NaN
# 247041       NaN          NaN          NaN
# 326393       NaN          NaN          NaN
# 392595       NaN          NaN          NaN
#
#                                      ProblemCode  Tonnage Completed Date  \
# 4607    Compactor is full and needs to be hauled     7.26     2021-01-14
# 5603    Compactor is full and needs to be hauled     6.10     2021-01-21
# 8484    Compactor is full and needs to be hauled     4.77     2021-01-30
# 11032   Compactor is full and needs to be hauled     8.90     2021-02-05
# 11936                                        NaN     9.15     2021-02-08
# ...                                          ...      ...            ...
# 413140                                       NaN     1.08     2024-01-23
# 181439                                       NaN    10.79     2022-06-06
# 247041                                       NaN     7.46     2022-11-25
# 326393                                       NaN    10.44     2023-06-12
# 392595                                       NaN     9.49     2023-11-10
#
#         Region  District Priority  Zip code         City State   Latitude  \
# 4607      42.0     323.0      NaN       NaN       ROGERS    AR  36.331300
# 5603      42.0     323.0      NaN       NaN       ROGERS    AR  36.331300
# 8484      42.0     323.0      NaN       NaN       ROGERS    AR  36.331300
# 11032     42.0     323.0      NaN       NaN       ROGERS    AR  36.331300
# 11936      NaN       NaN      NaN   72756.0       ROGERS    AR  36.331300
# ...        ...       ...      ...       ...          ...   ...        ...
# 413140     NaN       NaN      NaN   72712.0  BENTONVILLE    AR  36.346243
# 181439     NaN       NaN      NaN   72712.0  BENTONVILLE    AR  36.340990
# 247041     NaN       NaN      NaN   72712.0  BENTONVILLE    AR  36.340990
# 326393     NaN       NaN      NaN   72712.0  BENTONVILLE    AR  36.340990
# 392595     NaN       NaN      NaN   72712.0  BENTONVILLE    AR  36.340990
#
#         Longitude  Days Since Last Pickup
# 4607   -94.149054                     NaN
# 5603   -94.149054                     7.0
# 8484   -94.149054                     9.0
# 11032  -94.149054                     6.0
# 11936  -94.149054                     3.0
# ...           ...                     ...
# 413140 -94.195376                    13.0
# 181439 -94.200230                     NaN
# 247041 -94.200230                   172.0
# 326393 -94.200230                   199.0
# 392595 -94.200230                   151.0
#
# [413669 rows x 18 columns]

# %%
# First, let's identify all unique location IDs in the dataframe
unique_location_ids = df['Location ID'].unique()

# Plot tonnage over time for each unique location ID
plt.figure(figsize=(15, 10))

for location_id in unique_location_ids:
    # Filter the dataframe for the current location ID
    location_data = df[df['Location ID'] == location_id]
    # Plot the data with a marker for each point
    plt.plot(location_data['Completed Date'], location_data['Tonnage'], marker='o', label=f'Location {location_id}')

plt.figure(figsize=(15, 10))
plt.title('Tonnage Over Time for Each Store')
plt.xlabel('Completed Date')
plt.ylabel('Tonnage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
